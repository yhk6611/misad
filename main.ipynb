# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/gyn')

# %%
! pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
! git config --global user.email "yanghongkang1@gmail.com"
! git config --global user.name "yhk6611"

# %%
! git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/.git/

# %%
! git add -A
! git commit -m "first commit"
# Out:
# [master (root-commit) 02809df] first commit
#  37 files changed, 2149 insertions(+)
#  create mode 100644 20201205 B0742031.ipynb
#  create mode 100644 20201205 B0742031/e2270c3b-2f9a-458b-b582-c661eb83aeb6.csv
#  create mode 100644 Copy of Untitled3 (1).ipynb
#  create mode 100644 Copy of Untitled3.ipynb
#  create mode 100644 Copy of Welcome To Colaboratory
#  create mode 100644 Copy of Welcome To Colaboratory (1)
#  create mode 100644 Pyworkshop 20201205.ipynb
#  create mode 100644 Untitled
#  create mode 100644 Untitled (1)
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 Untitled1.ipynb
#  create mode 100644 Untitled10.ipynb
#  create mode 100644 Untitled11.ipynb
#  create mode 100644 Untitled12.ipynb
#  create mode 100644 Untitled13.ipynb
#  create mode 100644 Untitled14.ipynb
#  create mode 100644 Untitled15.ipynb
#  create mode 100644 Untitled16.ipynb
#  create mode 100644 Untitled17.ipynb
#  create mode 100644 Untitled18.ipynb
#  create mode 100644 Untitled19.ipynb
#  create mode 100644 Untitled2.ipynb
#  create mode 100644 Untitled20.ipynb
#  create mode 100644 Untitled21.ipynb
#  create mode 100644 Untitled3.ipynb
#  create mode 100644 Untitled4.ipynb
#  create mode 100644 Untitled5.ipynb
#  create mode 100644 Untitled6.ipynb
#  create mode 100644 Untitled7.ipynb
#  create mode 100644 Untitled8.ipynb
#  create mode 100644 Untitled9.ipynb
#  create mode 100644 main.ipynb
#  create mode 100644 python_workshop_20201205/DatasaurusDozen.tsv
#  create mode 100644 python_workshop_20201205/WHO_COVID-19.csv
#  create mode 100644 python_workshop_20201205/e2270c3b-2f9a-458b-b582-c661eb83aeb6.csv
#  create mode 100644 "\342\200\234\346\254\242\350\277\216\344\275\277\347\224\250 Colaboratory\342\200\235\347\232\204\345\211\257\346\234\254"
#  create mode 100644 "\347\254\254\344\270\211\351\241\214.ipynb"

# %%
! git remote add origin
